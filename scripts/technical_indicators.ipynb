# %%
import requests
from settings import settings

api_key = settings["api_key"]

url = f"https://www.alphavantage.co/query?function=WMA&symbol=IBM&interval=weekly&time_period=10&series_type=open&apikey={api_key}"

response = requests.get(url)
data = response.json()

data
# Out:
# {'Meta Data': {'1: Symbol': 'IBM',
#   '2: Indicator': 'Weighted Moving Average (WMA)',
#   '3: Last Refreshed': '2022-11-11',
#   '4: Interval': 'weekly',
#   '5: Time Period': 10,
#   '6: Series Type': 'open',
#   '7: Time Zone': 'US/Eastern'},
#  'Technical Analysis: WMA': {'2022-11-11': {'WMA': '127.2969'},
#   '2022-11-04': {'WMA': '125.5222'},
#   '2022-10-28': {'WMA': '123.4850'},
#   '2022-10-21': {'WMA': '122.7712'},
#   '2022-10-14': {'WMA': '123.8652'},
#   '2022-10-07': {'WMA': '125.4878'},
#   '2022-09-30': {'WMA': '127.1635'},
#   '2022-09-23': {'WMA': '128.7438'},
#   '2022-09-16': {'WMA': '129.7934'},
#   '2022-09-09': {'WMA': '130.2946'},
#   '2022-09-02': {'WMA': '131.4780'},
#   '2022-08-26': {'WMA': '132.3434'},
#   '2022-08-19': {'WMA': '131.7362'},
#   '2022-08-12': {'WMA': '132.1193'},
#   '2022-08-05': {'WMA': '132.8687'},
#   '2022-07-29': {'WMA': '134.0127'},
#   '2022-07-22': {'WMA': '135.6492'},
#   '2022-07-15': {'WMA': '135.1065'},
# ...
