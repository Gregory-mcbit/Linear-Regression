# %%
import settings
import requests

api_key = settings.settings["api_key"]
url = f"https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&topics=technology&apikey={api_key}"

response = requests.get(url)
data = response.json()
data
# Out:
# {'items': '50',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.',
#  'feed': [{'title': "Tech stocks have been crushed. What's next for the FAANGs? | Business",
#    'url': 'https://www.cnn.com/2022/11/14/investing/tech-stocks-faangs/index.html',
#    'time_published': '20221114T170000',
#    'authors': ['Paul R. La Monica'],
#    'summary': "Tech stocks have been crushed. What's next for the ...",
#    'banner_image': 'https://media.cnn.com/api/v1/images/stellar/prod/221108154139-meta-headquarters-menlo-park-restricted.jpg?c=16x9&q=h_144,w_256,c_fill',
#    'source': 'CNN',
#    'category_within_source': 'Markets',
#    'source_domain': 'www.cnn.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.266143'},
# ...
